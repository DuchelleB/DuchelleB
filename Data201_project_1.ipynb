# %% [markdown]
# # Health Nutrition and Population Statistics
#
# This dataset from the World Bank's Health, Nutrition, and Population Statistics offers a rich foundation for exploring health-related trends over time across various countries. It contains data fr various sources, such as UNICEF, WHO, US Census Bureau, local governments data, and many more. The data are fromom 1960 to 20 with 125,020 rows and 68 columns including columns for Country Name, Country Code, Indicator Name, and Indicator Code, as well as annual data for each year in this range.3. Themes include global surgery, health financing, HIV/AIDS, immunization, infectious diseases, medical resources and usage, noncommunicable diseases, nutrition, population dynamics, reproductive health, universal health coverage, and water and sanitation.

# %%
from pathlib import Path
print(Path.cwd())
# Out:
# /Users/gimle/Data 201/Data 201 projects

# %%
# Cell 1
import pandas as pd

# Load the dataset to inspect its structure and contents
file_path = "/Users/gimle/Data 201/HNP_Stats_CSV/HNP_StatsCSV.csv"
data = pd.read_csv(file_path)

# Display the first few rows and summary information about the dataset
data.head(10), data.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125020 entries, 0 to 125019
# Data columns (total 68 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    125020 non-null  object
#  1   Country Code    125020 non-null  object
#  2   Indicator Name  125020 non-null  object
#  3   Indicator Code  125020 non-null  object
#  4   1960            41829 non-null   float64
#  5   1961            42383 non-null   float64
#  6   1962            42497 non-null   float64
#  7   1963            42546 non-null   float64
#  8   1964            42602 non-null   float64
#  9   1965            42762 non-null   float64
#  10  1966            42703 non-null   float64
#  11  1967            42761 non-null   float64
#  12  1968            42831 non-null   float64
#  13  1969            42928 non-null   float64
#  14  1970            44334 non-null   float64
#  15  1971            45054 non-null   float64
#  16  1972            45123 non-null   float64
#  17  1973            45150 non-null   float64
#  18  1974            45184 non-null   float64
#  19  1975            46139 non-null   float64
#  20  1976            46214 non-null   float64
#  21  1977            46221 non-null   float64
#  22  1978            46293 non-null   float64
#  23  1979            46372 non-null   float64
#  24  1980            47202 non-null   float64
#  25  1981            47457 non-null   float64
#  26  1982            47258 non-null   float64
#  27  1983            47360 non-null   float64
#  28  1984            47567 non-null   float64
#  29  1985            47861 non-null   float64
#  30  1986            48252 non-null   float64
#  31  1987            48254 non-null   float64
#  32  1988            48089 non-null   float64
#  33  1989            48338 non-null   float64
#  34  1990            60651 non-null   float64
#  35  1991            61804 non-null   float64
#  36  1992            62097 non-null   float64
#  37  1993            61991 non-null   float64
#  38  1994            61944 non-null   float64
#  39  1995            62171 non-null   float64
#  40  1996            62428 non-null   float64
#  41  1997            62082 non-null   float64
#  42  1998            62388 non-null   float64
#  43  1999            63343 non-null   float64
#  44  2000            81718 non-null   float64
#  45  2001            77929 non-null   float64
#  46  2002            78269 non-null   float64
#  47  2003            78579 non-null   float64
#  48  2004            79013 non-null   float64
#  49  2005            81473 non-null   float64
#  50  2006            80127 non-null   float64
#  51  2007            79579 non-null   float64
#  52  2008            79501 non-null   float64
#  53  2009            80036 non-null   float64
#  54  2010            84504 non-null   float64
#  55  2011            81024 non-null   float64
#  56  2012            80839 non-null   float64
#  57  2013            80426 non-null   float64
#  58  2014            81088 non-null   float64
#  59  2015            83093 non-null   float64
#  60  2016            80515 non-null   float64
#  61  2017            81108 non-null   float64
#  62  2018            81587 non-null   float64
#  63  2019            82358 non-null   float64
#  64  2020            74328 non-null   float64
#  65  2021            71103 non-null   float64
#  66  2022            64614 non-null   float64
#  67  2023            39185 non-null   float64
# dtypes: float64(64), object(4)
# memory usage: 64.9+ MB
# (                  Country Name Country Code  \
#  0  Africa Eastern and Southern          AFE
#  1  Africa Eastern and Southern          AFE
#  2  Africa Eastern and Southern          AFE
#  3  Africa Eastern and Southern          AFE
#  4  Africa Eastern and Southern          AFE
#  5  Africa Eastern and Southern          AFE
#  6  Africa Eastern and Southern          AFE
#  7  Africa Eastern and Southern          AFE
#  8  Africa Eastern and Southern          AFE
#  9  Africa Eastern and Southern          AFE
#
#                                        Indicator Name  Indicator Code  \
#  0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
#  1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL
#  2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL
#  3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS
#  4        Adults (ages 15-49) newly infected with HIV     SH.HIV.INCD
#  5                      Age at first marriage, female  SP.DYN.SMAM.FE
#  6                        Age at first marriage, male  SP.DYN.SMAM.MA
#  7  Age dependency ratio (% of working-age populat...     SP.POP.DPND
#  8                          Age dependency ratio, old  SP.POP.DPND.OL
#  9                        Age dependency ratio, young  SP.POP.DPND.YG
#
#           1960        1961        1962        1963        1964        1965  \
#  0  140.180526  140.810248  141.664168  142.324951  143.456933  144.331150
#  1         NaN         NaN         NaN         NaN         NaN         NaN
#  2         NaN         NaN         NaN         NaN         NaN         NaN
#  3         NaN         NaN         NaN         NaN         NaN         NaN
#  4         NaN         NaN         NaN         NaN         NaN         NaN
#  5         NaN         NaN         NaN         NaN         NaN         NaN
#  6         NaN         NaN         NaN         NaN         NaN         NaN
#  7   89.594604   89.873370   90.191721   90.574678   90.952719   91.346821
#  8    5.626944    5.598776    5.571718    5.549702    5.534236    5.526348
#  9   83.668705   83.936992   84.243994   84.613140   84.994512   85.398509
#
#     ...        2014        2015        2016        2017       2018       2019  \
#  0  ...  107.697715  105.501833  103.222825  100.963526  99.491703  99.085572
#  1  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  2  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  3  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  4  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  5  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  6  ...         NaN         NaN         NaN         NaN        NaN        NaN
#  7  ...   85.499375   84.957551   84.439468   83.930980  83.342388  82.692059
#  8  ...    5.509918    5.544147    5.584600    5.631777   5.677017   5.718424
#  9  ...   78.874913   78.311969   77.798386   77.297024  76.690679  76.028564
#
#          2020       2021       2022       2023
#  0  97.413585  96.181442  94.688181        NaN
#  1        NaN        NaN        NaN        NaN
#  2        NaN        NaN        NaN        NaN
#  3        NaN        NaN        NaN        NaN
#  4        NaN        NaN        NaN        NaN
#  5        NaN        NaN        NaN        NaN
#  6        NaN        NaN        NaN        NaN
#  7  81.968963  81.189988  80.385344  79.554074
#  8   5.733111   5.706199   5.662353   5.641678
#  9  75.310862  74.565149  73.799990  72.978971
#
#  [10 rows x 68 columns],
#  None)

# %%
from IPython.display import display, HTML

# Display the DataFrame with scrollable output
display(HTML(data.to_html(max_rows= 10, max_cols=68)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Indicator Name</th>
#       <th>Indicator Code</th>
#       <th>1960</th>
#       <th>1961</th>
#       <th>1962</th>
#       <th>1963</th>
#       <th>1964</th>
#       <th>1965</th>
#       <th>1966</th>
#       <th>1967</th>
#       <th>1968</th>
#       <th>1969</th>
#       <th>1970</th>
#       <th>1971</th>
#       <th>1972</th>
#       <th>1973</th>
#       <th>1974</th>
#       <th>1975</th>
#       <th>1976</th>
#       <th>1977</th>
#       <th>1978</th>
#       <th>1979</th>
#       <th>1980</th>
#       <th>1981</th>
#       <th>1982</th>
#       <th>1983</th>
#       <th>1984</th>
#       <th>1985</th>
#       <th>1986</th>
#       <th>1987</th>
#       <th>1988</th>
#       <th>1989</th>
#       <th>1990</th>
#       <th>1991</th>
#       <th>1992</th>
#       <th>1993</th>
#       <th>1994</th>
#       <th>1995</th>
#       <th>1996</th>
#       <th>1997</th>
#       <th>1998</th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td>SP.ADO.TFRT</td>
#       <td>140.180526</td>
#       <td>140.810248</td>
#       <td>141.664168</td>
#       <td>142.324951</td>
#       <td>143.456933</td>
#       <td>144.33115</td>
#       <td>145.295946</td>
#       <td>145.871493</td>
#       <td>145.748064</td>
#       <td>148.012004</td>
#       <td>149.579704</td>
#       <td>152.84677</td>
#       <td>153.951117</td>
#       <td>152.570502</td>
#       <td>152.504673</td>
#       <td>151.867914</td>
#       <td>150.533609</td>
#       <td>148.931096</td>
#       <td>146.644103</td>
#       <td>145.48472</td>
#       <td>143.753438</td>
#       <td>142.558132</td>
#       <td>141.191951</td>
#       <td>139.763807</td>
#       <td>138.785843</td>
#       <td>137.953223</td>
#       <td>136.128479</td>
#       <td>135.346146</td>
#       <td>133.911118</td>
#       <td>132.422604</td>
#       <td>132.845311</td>
#       <td>131.922595</td>
#       <td>128.650227</td>
#       <td>129.800646</td>
#       <td>128.792351</td>
#       <td>127.306551</td>
#       <td>128.239448</td>
#       <td>125.261998</td>
#       <td>123.860303</td>
#       <td>124.958024</td>
#       <td>123.134769</td>
#       <td>123.629170</td>
#       <td>121.936911</td>
#       <td>119.557516</td>
#       <td>118.823212</td>
#       <td>117.584240</td>
#       <td>116.401307</td>
#       <td>115.060877</td>
#       <td>114.933409</td>
#       <td>112.602371</td>
#       <td>111.758713</td>
#       <td>111.558595</td>
#       <td>109.532170</td>
#       <td>108.092796</td>
#       <td>107.697715</td>
#       <td>105.501833</td>
#       <td>103.222825</td>
#       <td>100.963526</td>
#       <td>99.491703</td>
#       <td>99.085572</td>
#       <td>97.413585</td>
#       <td>96.181442</td>
#       <td>94.688181</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) and children (0-14 years) living with HIV</td>
#       <td>SH.HIV.TOTL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) and children (ages 0-14) newly infected with HIV</td>
#       <td>SH.HIV.INCD.TL</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) living with HIV</td>
#       <td>SH.DYN.AIDS</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15-49) newly infected with HIV</td>
#       <td>SH.HIV.INCD</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <t

# %%
# Set pandas options to display numbers in decimal format
pd.options.display.float_format = '{:.5f}'.format # "{:.5f}.format" will display numbers with 5 decimal places.

# %%
# Define the path to the folder containing the files
folder_path = r"/Users/gimle/Data 201/HNP_Stats_CSV"

# Import each metadata file
country_data = pd.read_csv(f"{folder_path}/HNP_StatsCountry.csv")
country_series_data = pd.read_csv(f"{folder_path}/HNP_Statscountry-series.csv")
footnote_data = pd.read_csv(f"{folder_path}/HNP_Statsfootnote.csv")
series_data = pd.read_csv(f"{folder_path}/HNP_StatsSeries.csv")
series_time_data = pd.read_csv(f"{folder_path}/HNP_Statsseries-time.csv")

# Display the first few rows of each dataset to verify the import
country_data.head(), country_series_data.head(), footnote_data.head(), series_data.head(), series_time_data.head()
# Out:
# (  Country Code                   Short Name                   Table Name  \
#  0          ABW                        Aruba                        Aruba
#  1          AFE  Africa Eastern and Southern  Africa Eastern and Southern
#  2          AFG                  Afghanistan                  Afghanistan
#  3          AFW   Africa Western and Central   Africa Western and Central
#  4          AGO                       Angola                       Angola
#
#                        Long Name 2-alpha code   Currency Unit  \
#  0                         Aruba           AW   Aruban florin
#  1   Africa Eastern and Southern           ZH             NaN
#  2  Islamic State of Afghanistan           AF  Afghan afghani
#  3    Africa Western and Central           ZI             NaN
#  4   People's Republic of Angola           AO  Angolan kwanza
#
#                                         Special Notes  \
#  0                                                NaN
#  1  26 countries, stretching from the Red Sea in t...
#  2  The reporting period for national accounts dat...
#  3  22 countries, stretching from the westernmost ...
#  4  The World Bank systematically assesses the app...
#
#                        Region         Income Group WB-2 code  ...  \
#  0  Latin America & Caribbean          High income        AW  ...
#  1                        NaN                  NaN        ZH  ...
#  2                 South Asia           Low income        AF  ...
#  3                        NaN                  NaN        ZI  ...
#  4         Sub-Saharan Africa  Lower middle income        AO  ...
#
#       Government Accounting concept  \
#  0                              NaN
#  1                              NaN
#  2  Consolidated central government
#  3                              NaN
#  4     Budgetary central government
#
#                       IMF data dissemination standard Latest population census  \
#  0  Enhanced General Data Dissemination System (e-...          2020 (expected)
#  1                                                NaN                      NaN
#  2  Enhanced General Data Dissemination System (e-...                     1979
#  3                                                NaN                      NaN
#  4  Enhanced General Data Dissemination System (e-...                     2014
#
#                    Latest household survey  \
#  0                                     NaN
#  1                                     NaN
#  2     Demographic and Health Survey, 2015
#  3                                     NaN
#  4  Demographic and Health Survey, 2015/16
#
#    Source of most recent Income and expenditure data  \
#  0                                               NaN
#  1                                               NaN
#  2        Integrated household survey (IHS), 2016/17
#  3                                               NaN
#  4        Integrated household survey (IHS), 2008/09
#
#    Vital registration complete  Latest agricultural census  \
#  0                         Yes                         NaN
#  1                         NaN                         NaN
#  2                         NaN                         NaN
#  3                         NaN                         NaN
#  4                         NaN                         NaN
#
#     Latest industrial data Latest trade data Latest water withdrawal data
#  0                     NaN        2018.00000                          NaN
#  1                     NaN               NaN                          NaN
#  2                     NaN        2018.00000                   2000.00000
#  3                     NaN               NaN                          NaN
#  4                     NaN        2018.00000                   2005.00000
#
#  [5 rows x 31 columns],
#    CountryCode         SeriesCode  \
#  0         ABW        SM.POP.NETM
#  1         ABW  SP.DYN.LE00.FE.IN
#  2         ABW  SP.DYN.LE00.MA.IN
#  3         ABW        SP.POP.TOTL
#  4         ABW     SP.DYN.LE00.IN
#
#                                           DESCRIPTION
#  0  Data source: United Nations World Population P...
#  1  Data source: United Nations World Population P...
#  2  Data source: United Nations World Population P...
#  3  Data source: United Nations World Population P...
#  4  Data source: United Nations World Population P...  ,
#    CountryCode      SeriesCode    Year                 DESCRIPTION
#  0         ABW  SP.DYN.SMAM.MA  YR2010  Source: Aruba 2010 Census.
#  1         ABW  SP.DYN.SMAM.MA  YR2000  Source: Aruba 2000 Census.
#  2         ABW  SP.DYN.SMAM.MA  YR1991  Source: Aruba 1991 Census.
#  3         ABW  SP.DYN.SMAM.MA  YR1981  Source: Aruba 1981 Census.
#  4         ABW  SP.DYN.SMAM.FE  YR2010  Source: Aruba 2010 Census.,
#           Series Code                                 Topic  \
#  0        HD.HCI.OVRL  Public Sector: Policy & institutions
#  1     HD.HCI.OVRL.FE  Public Sector: Policy & institutions
#  2     HD.HCI.OVRL.LB  Public Sector: Policy & institutions
#  3  HD.HCI.OVRL.LB.FE  Public Sector: Policy & institutions
#  4  HD.HCI.OVRL.LB.MA  Public Sector: Policy & institutions
#
#                                        Indicator Name Short definition  \
#  0              Human capital index (HCI) (scale 0-1)              NaN
#  1      Human capital index (HCI), female (scale 0-1)              NaN
#  2  Human capital index (HCI), lower bound (scale ...              NaN
#  3  Human capital index (HCI), female, lower bound...              NaN
#  4  Human capital index (HCI), male, lower bound (...              NaN
#
#                                       Long definition  Unit of measure  \
#  0  The HCI calculates the contributions of health...              NaN
#  1  The HCI calculates the contributions of health...              NaN
#  2  The HCI lower bound reflects uncertainty in th...              NaN
#  3  The HCI lower bound reflects uncertainty in th...              NaN
#  4  The HCI lower bound reflects uncertainty in th...              NaN
#
#    Periodicity  Base Period  Other notes Aggregation method  \
#  0         NaN          NaN          NaN                NaN
#  1         NaN          NaN          NaN                NaN
#  2         NaN          NaN          NaN                NaN
#  3         NaN          NaN          NaN                NaN
#  4         NaN          NaN          NaN                NaN
#
#    Limitations and exceptions Notes from original source General comments  \
#  0                        NaN                        NaN              NaN
#  1                        NaN                        NaN              NaN
#  2                        NaN                        NaN              NaN
#  3                        NaN                        NaN              NaN
#  4                        NaN                        NaN              NaN
#
#                                                Source  \
#  0  World Bank staff calculations based on the met...
#  1  World Bank staff calculations based on the met...
#  2  World Bank staff calculations based on the met...
#  3  World Bank staff calculations based on the met...
#  4  World Bank staff calculations based on the met...
#
#    Statistical concept and methodology Development relevance  \
#  0                                 NaN                   NaN
#  1                                 NaN                   NaN
#  2                                 NaN                   NaN
#  3                                 NaN                   NaN
#  4                                 NaN                   NaN
#
#     Related source links  Other web links  Related indicators License Type
#  0                   NaN              NaN                 NaN    CC BY-4.0
#  1                   NaN              NaN                 NaN    CC BY-4.0
#  2                   NaN              NaN                 NaN    CC BY-4.0
#  3                   NaN              NaN                 NaN    CC BY-4.0
#  4                   NaN              NaN                 NaN    CC BY-4.0  ,
#         SeriesCode    Year                                        DESCRIPTION
#  0     SP.UWT.TFRT  YR1990  Averages for regions/groups are based on count...
#  1  SP.REG.DTHS.ZS  YR1990  Averages for regions/groups are based on count...
#  2  SH.FPL.SATM.ZS  YR1990  Averages for regions/groups are based on count...
#  3     SP.DYN.WFRT  YR1990  Averages for regions/groups are based on count...
#  4  SH.MED.CMHW.P3  YR1990  Averages for regions/groups are based on count...)

# %% [markdown]
# ### HNP_StatsCountry.csv:
# Provides country-specific information, including Country Code, Region, Income Group, and Currency Unit.
# Useful for adding contextual details about each country, like income level or region, which can aid in regional or economic analyses.
#
# ### HNP_Statscountry-series.csv:
# Contains CountryCode, SeriesCode, and a DESCRIPTION field with notes about specific indicators for each country.
# This could help in understanding indicator data sources or nuances in how data is collected for different countries.
#
# ### HNP_Statsfootnote.csv:
# Lists CountryCode, SeriesCode, Year, and DESCRIPTION, which appears to include specific data source notes for certain years and indicators.
# This file could be useful for interpreting changes or anomalies in specific years, especially if certain years have unique data collection methods.
#
# ### HNP_StatsSeries.csv:
# Provides details about indicators, such as Topic, Indicator Name, Short Definition, Long Definition, and Unit of Measure.
# This file is highly valuable for understanding what each indicator represents, and could be merged with the main dataset to add indicator descriptions.
#
# ### HNP_Statsseries-time.csv:
# Includes SeriesCode, Year, and additional notes for specific years.
# This may provide time-specific notes about how indicators are calculated or reported, aiding in any time-trend analysis.
#
# The following files will be especially valuable to integrate with the main dataset:
# ### HNP_StatsCountry.csv
# This file offers rich contextual information about each country, including its region, income group, and other socioeconomic details. By adding this data, I will be able to filter and group countries by region or income group, which will enable more nuanced and meaningful comparisons, particularly for regional and income-based analyses.
#
# ### HNP_StatsSeries.csv
# This file provides detailed descriptions of each indicator, such as the Indicator Name, Topic, and Unit of Measure. Integrating this information will clarify what each column in the main dataset represents, allowing me to directly reference indicator descriptions and topics. This addition will make the dataset more interpretable and enhance the depth of analysis.
#
# After viewing the first rows of those files, I will proceed with merging the HNP_StatsCountry.csv and HNP_StatsSeries.csv files with the main dataset, focusing on enhancing interpretability and adding valuable context to each country's indicators.

# %%
# Reload the main dataset
main_data = data
# Perform the merge with main dataset
# First, add country-specific information from HNP_StatsCountry.csv
merged_data1 = main_data.merge(country_data, how='left', left_on='Country Code', right_on='Country Code')

# Next, add indicator descriptions from HNP_StatsSeries.csv
merged_data2 = merged_data1.merge(series_data, how='left', left_on='Indicator Code', right_on='Series Code')

# Display the first few rows of the merged dataset to confirm integration
merged_data2.head(10)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
# 5  Africa Eastern and Southern          AFE
# 6  Africa Eastern and Southern          AFE
# 7  Africa Eastern and Southern          AFE
# 8  Africa Eastern and Southern          AFE
# 9  Africa Eastern and Southern          AFE
#
#                                     Indicator Name_x  Indicator Code  \
# 0  Adolescent fertility rate (births per 1,000 wo...     SP.ADO.TFRT
# 1  Adults (ages 15+) and children (0-14 years) li...     SH.HIV.TOTL
# 2  Adults (ages 15+) and children (ages 0-14) new...  SH.HIV.INCD.TL
# 3                  Adults (ages 15+) living with HIV     SH.DYN.AIDS
# 4        Adults (ages 15-49) newly infected with HIV     SH.HIV.INCD
# 5                      Age at first marriage, female  SP.DYN.SMAM.FE
# 6                        Age at first marriage, male  SP.DYN.SMAM.MA
# 7  Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 8                          Age dependency ratio, old  SP.POP.DPND.OL
# 9                        Age dependency ratio, young  SP.POP.DPND.YG
#
#        1960      1961      1962      1963      1964      1965  ...  \
# 0 140.18053 140.81025 141.66417 142.32495 143.45693 144.33115  ...
# 1       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 2       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 3       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 4       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 5       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 6       NaN       NaN       NaN       NaN       NaN       NaN  ...
# 7  89.59460  89.87337  90.19172  90.57468  90.95272  91.34682  ...
# 8   5.62694   5.59878   5.57172   5.54970   5.53424   5.52635  ...
# 9  83.66871  83.93699  84.24399  84.61314  84.99451  85.39851  ...
#
#                           Limitations and exceptions  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  The estimates by age may be affected by age mi...
# 6  The estimates by age may be affected by age mi...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                           Notes from original source  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Note that the SMAM takes a single point in tim...
# 6  Note that the SMAM takes a single point in tim...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                                     General comments  \
# 0  This is the Sustainable Development Goal indic...
# 1                                                NaN
# 2  This indicator is related to Sustainable Devel...
# 3                                                NaN
# 4  This indicator is related to Sustainable Devel...
# 5                                                NaN
# 6                                                NaN
# 7  Relevance to gender indicator: this indicator ...
# 8                                                NaN
# 9                                                NaN
#
#                                               Source  \
# 0  United Nations Population Division, World Popu...
# 1                                  UNAIDS estimates.
# 2                                  UNAIDS estimates.
# 3                                  UNAIDS estimates.
# 4                                  UNAIDS estimates.
# 5  United Nations, Department of Economic and Soc...
# 6  United Nations, Department of Economic and Soc...
# 7  World Bank staff estimates based on age distri...
# 8  World Bank staff estimates based on age distri...
# 9  World Bank staff estimates based on age distri...
#
#                  Statistical concept and methodology  \
# 0  Reproductive health is a state of physical and...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Dependency ratios capture variations in the pr...
# 8  Dependency ratios capture variations in the pr...
# 9  Dependency ratios capture variations in the pr...
#
#                                Development relevance  Related source links  \
# 0                                                NaN                   NaN
# 1                                                NaN                   NaN
# 2  Despite the existence of effective medications...                   NaN
# 3                                                NaN                   NaN
# 4  Despite the existence of effective medications...                   NaN
# 5                                                NaN                   NaN
# 6                                                NaN                   NaN
# 7  Patterns of development in a country are partl...                   NaN
# 8  Patterns of development in a country are partl...                   NaN
# 9  Patterns of development in a country are partl...                   NaN
#
#    Other web links  Related indicators  License Type
# 0              NaN                 NaN     CC BY-4.0
# 1              NaN                 NaN     CC BY-4.0
# 2              NaN                 NaN     CC BY-4.0
# 3              NaN                 NaN     CC BY-4.0
# 4              NaN                 NaN     CC BY-4.0
# 5              NaN                 NaN     CC BY-4.0
# 6              NaN                 NaN     CC BY-4.0
# 7              NaN                 NaN     CC BY-4.0
# 8              NaN                 NaN     CC BY-4.0
# 9              NaN                 NaN     CC BY-4.0
#
# [10 rows x 118 columns]

# %% [markdown]
# In this step, I focused on preparing and wrangling the dataset to make it suitable for analysis. Using Python's pandas and numpy libraries, I started by identifying and handling missing values, filtering irrelevant data, and isolating specific indicators for analysis. To guide my selection, I first extracted a unique list of indicators in the dataset to better understand the scope of available variables and to select those most relevant for the analysis.

# %%
# Display unique indicators
unique_indicators = merged_data2['Indicator Name_x'].unique()
unique_indicators_df = pd.DataFrame(unique_indicators, columns=["Indicator Name"]).sort_values(by="Indicator Name").reset_index(drop=True)

# Show the unique indicators
unique_indicators_df
# Out:
#                                         Indicator Name
# 0             AIDS estimated deaths (UNAIDS estimates)
# 1    ARI treatment (% of children under 5 taken to ...
# 2    Adolescent fertility rate (births per 1,000 wo...
# 3    Adults (ages 15+) and children (0-14 years) li...
# 4    Adults (ages 15+) and children (ages 0-14) new...
# ..                                                 ...
# 465           Wanted fertility rate (births per woman)
# 466  Women who were first married by age 15 (% of w...
# 467  Women who were first married by age 18 (% of w...
# 468  Women's share of population ages 15+ living wi...
# 469  Young people (ages 15-24) newly infected with HIV
#
# [470 rows x 1 columns]

# %%
# Define the path in the Documents folder
file_path = r"/Users/gimle/Data 201/HNP_Stats_CSV/unique_indicators.csv"

# Save the DataFrame as a CSV file to this path
unique_indicators_df.to_csv(file_path, index=False)

# %%
# Check for missing values in each column
missing_values = merged_data2.isnull().sum().sort_values(ascending=False)

# Display columns with missing values
missing_values[missing_values > 0]
# Out:
# Unit of measure         125020
# Other notes             125020
# Related indicators      125020
# Other web links         125020
# Related source links    125020
#                          ...
# 2-alpha code              1410
# WB-2 code                  940
# Long Name                  470
# Table Name                 470
# Short Name                 470
# Length: 109, dtype: int64

# %%
# Identify year columns (assuming they are numeric and represent years)
year_columns = [col for col in merged_data2.columns if col.isdigit()]

# Separate the year columns and non-year columns
year_data = merged_data2[year_columns]
non_year_data = merged_data2.drop(columns=year_columns)

# Drop columns with more than 75% missing values in non-year data only
threshold = len(non_year_data) * 0.75
cleaned_non_year_data = non_year_data.dropna(axis=1, thresh=threshold)

# Recombine the year data with the cleaned non-year data
merged_data = pd.concat([cleaned_non_year_data, year_data], axis=1)

# Display the updated data
from IPython.display import display, HTML
display(HTML(merged_data.to_html(max_rows=10, max_cols=40)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Indicator Name_x</th>
#       <th>Indicator Code</th>
#       <th>Short Name</th>
#       <th>Table Name</th>
#       <th>Long Name</th>
#       <th>2-alpha code</th>
#       <th>Currency Unit</th>
#       <th>Region</th>
#       <th>Income Group</th>
#       <th>WB-2 code</th>
#       <th>National accounts base year</th>
#       <th>SNA price valuation</th>
#       <th>System of National Accounts</th>
#       <th>Latest population census</th>
#       <th>Series Code</th>
#       <th>Topic</th>
#       <th>Indicator Name_y</th>
#       <th>Long definition</th>
#       <th>...</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td>SP.ADO.TFRT</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SP.ADO.TFRT</td>
#       <td>Health: Reproductive health</td>
#       <td>Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td>Adolescent fertility rate is the number of births per 1,000 women ages 15-19.</td>
#       <td>...</td>
#       <td>118.82321</td>
#       <td>117.58424</td>
#       <td>116.40131</td>
#       <td>115.06088</td>
#       <td>114.93341</td>
#       <td>112.60237</td>
#       <td>111.75871</td>
#       <td>111.55859</td>
#       <td>109.53217</td>
#       <td>108.09280</td>
#       <td>107.69771</td>
#       <td>105.50183</td>
#       <td>103.22283</td>
#       <td>100.96353</td>
#       <td>99.49170</td>
#       <td>99.08557</td>
#       <td>97.41358</td>
#       <td>96.18144</td>
#       <td>94.68818</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) and children (0-14 years) living with HIV</td>
#       <td>SH.HIV.TOTL</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SH.HIV.TOTL</td>
#       <td>Health: Risk factors</td>
#       <td>Adults (ages 15+) and children (0-14 years) living with HIV</td>
#       <td>Adults and children living with HIV refers to the number of people ages 0-49 (adult ages 15-49 and children ages 0-14) who are infected with HIV.</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) and children (ages 0-14) newly infected with HIV</td>
#       <td>SH.HIV.INCD.TL</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SH.HIV.INCD.TL</td>
#       <td>Health: Risk factors</td>
#       <td>Adults (ages 15+) and children (ages 0-14) newly infected with HIV</td>
#       <td>Number of adults (ages 15+) and children (ages 0-14) newly infected with HIV.</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) living with HIV</td>
#       <td>SH.DYN.AIDS</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SH.DYN.AIDS</td>
#       <td>Health: Risk factors</td>
#       <td>Adults (ages 15+) living with HIV</td>
#       <td>Adults living with HIV refers to the number of people ages 15-49 who are infected with HIV.</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15-49) newly infected with HIV</td>
#       <td>SH.HIV.INCD</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>ZH</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>SH.HIV.INCD</td>
#       <td>Health: Risk factors</td>
#       <td>Adults (ages 15-49) newly infected with HIV</td>
#       <td>Number of adults (ages 15-49) newly infected with HIV.</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>125015</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Wanted fertility rate (births per woman)</td>
#       <td>SP.DYN.WFRT</td>
#       <td>Zimbabwe</td>
#       <td>Zimbabwe</td>
#       <td>Republic of Zimbabwe</td>
#       <td>ZW</td>
#       <td>Zimbabwean

# %% [markdown]
# # Scatterplot fertility vs education
# For my part of this project we thought we could try to see if there was a noticable correlation between early births and secondary school attendance for girls. This required some EDA, and to make that task easier we decided to focus on two years, specifically 1999 and 2019 just to see what the effect of 20 years had on the distribution.

# %%
# We will only be comparing fertility and education between 1993 and 2020 so I deselect all other columns
keep_col = [
    'Country Name', 
    'Region', 
    'Indicator Name_x',
    '1999', 
    '2019']

filtered_merged = merged_data[keep_col]
# We can select out all the 'region' statistics by dropping those countries without a region signifier
filtered_merged = filtered_merged.dropna(subset=['Region'])

# %%
# I want to look at fertility rates amongst young women, and how that might impact their education
fertility = filtered_merged[filtered_merged['Indicator Name_x']=='Adolescent fertility rate (births per 1,000 women ages 15-19)']
secondary = filtered_merged[filtered_merged['Indicator Name_x']== 'School enrollment, secondary, female (% gross)']

# %%
# Pivoting step, so that the values 
pivot_fert1 = fertility.pivot(index=['Country Name', 'Region'], 
                              columns='Indicator Name_x', 
                              values=['1999']).rename(
                                                columns={'Adolescent fertility rate (births per 1,000 women ages 15-19)': 'Fertility Rate 1999'})

pivot_fert2 = fertility.pivot(index=['Country Name', 'Region'], 
                              columns='Indicator Name_x', 
                              values=['2019']).rename(
                                                columns={'Adolescent fertility rate (births per 1,000 women ages 15-19)': 'Fertility Rate 2019'})

display(HTML(pivot_fert1.to_html(max_rows=10, max_cols=6)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>1999</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Indicator Name_x</th>
#       <th>Fertility Rate 1999</th>
#     </tr>
#     <tr>
#       <th>Country Name</th>
#       <th>Region</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Afghanistan</th>
#       <th>South Asia</th>
#       <td>154.41600</td>
#     </tr>
#     <tr>
#       <th>Albania</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>16.09800</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>10.14000</td>
#     </tr>
#     <tr>
#       <th>American Samoa</th>
#       <th>East Asia &amp; Pacific</th>
#       <td>50.39700</td>
#     </tr>
#     <tr>
#       <th>Andorra</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>10.10000</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Virgin Islands (U.S.)</th>
#       <th>Latin America &amp; Caribbean</th>
#       <td>63.22900</td>
#     </tr>
#     <tr>
#       <th>West Bank and Gaza</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>94.60900</td>
#     </tr>
#     <tr>
#       <th>Yemen, Rep.</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>113.66200</td>
#     </tr>
#     <tr>
#       <th>Zambia</th>
#       <th>Sub-Saharan Africa</th>
#       <td>158.03400</td>
#     </tr>
#     <tr>
#       <th>Zimbabwe</th>
#       <th>Sub-Saharan Africa</th>
#       <td>100.36900</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Pivoting and renaming the columns

pivot_sec1 = secondary.pivot(index=['Country Name', 'Region'],
                             columns='Indicator Name_x', 
                             values=['1999']).rename(
                                            columns={'School enrollment, secondary, female (% gross)': 'Secondary Schooling 1999'})

pivot_sec2 = secondary.pivot(index=['Country Name', 'Region'],
                             columns='Indicator Name_x', 
                             values=['2019']).rename(
                                            columns={'School enrollment, secondary, female (% gross)': 'Secondary Schooling 2019'})
# a check
display(HTML(pivot_sec2.to_html(max_rows= 10, max_cols=6)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>2019</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Indicator Name_x</th>
#       <th>Secondary Schooling 2019</th>
#     </tr>
#     <tr>
#       <th>Country Name</th>
#       <th>Region</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Afghanistan</th>
#       <th>South Asia</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Albania</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>95.76969</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>American Samoa</th>
#       <th>East Asia &amp; Pacific</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Andorra</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>95.46256</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Virgin Islands (U.S.)</th>
#       <th>Latin America &amp; Caribbean</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>West Bank and Gaza</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>91.69852</td>
#     </tr>
#     <tr>
#       <th>Yemen, Rep.</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Zambia</th>
#       <th>Sub-Saharan Africa</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Zimbabwe</th>
#       <th>Sub-Saharan Africa</th>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Merging each category with itself
fert_comb = pivot_fert1.merge(pivot_fert2, on=['Country Name', 'Region'], how='outer')
secondary_comb = pivot_sec1.merge(pivot_sec2, on=['Country Name', 'Region'], how='outer')

# %%
# final merge
secondary_v_fertility = fert_comb.merge(secondary_comb, on=['Country Name', 'Region'], how='outer')
display(HTML(secondary_v_fertility.to_html(max_rows=10, max_cols=6)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th></th>
#       <th>1999</th>
#       <th>2019</th>
#       <th>1999</th>
#       <th>2019</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>Indicator Name_x</th>
#       <th>Fertility Rate 1999</th>
#       <th>Fertility Rate 2019</th>
#       <th>Secondary Schooling 1999</th>
#       <th>Secondary Schooling 2019</th>
#     </tr>
#     <tr>
#       <th>Country Name</th>
#       <th>Region</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Afghanistan</th>
#       <th>South Asia</th>
#       <td>154.41600</td>
#       <td>86.80300</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Albania</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>16.09800</td>
#       <td>15.01300</td>
#       <td>66.48526</td>
#       <td>95.76969</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>10.14000</td>
#       <td>12.30300</td>
#       <td>65.93951</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>American Samoa</th>
#       <th>East Asia &amp; Pacific</th>
#       <td>50.39700</td>
#       <td>30.65000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Andorra</th>
#       <th>Europe &amp; Central Asia</th>
#       <td>10.10000</td>
#       <td>5.98500</td>
#       <td>NaN</td>
#       <td>95.46256</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>Virgin Islands (U.S.)</th>
#       <th>Latin America &amp; Caribbean</th>
#       <td>63.22900</td>
#       <td>31.85000</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>West Bank and Gaza</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>94.60900</td>
#       <td>45.98200</td>
#       <td>74.43414</td>
#       <td>91.69852</td>
#     </tr>
#     <tr>
#       <th>Yemen, Rep.</th>
#       <th>Middle East &amp; North Africa</th>
#       <td>113.66200</td>
#       <td>57.83000</td>
#       <td>20.00627</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Zambia</th>
#       <th>Sub-Saharan Africa</th>
#       <td>158.03400</td>
#       <td>122.83600</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Zimbabwe</th>
#       <th>Sub-Saharan Africa</th>
#       <td>100.36900</td>
#       <td>97.35400</td>
#       <td>36.95415</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>

# %%
secondary_v_fertility.columns = secondary_v_fertility.columns.get_level_values(1)

# %%
secondary_v_fertility['Schooling Difference'] = (
    secondary_v_fertility['Secondary Schooling 2019'] - secondary_v_fertility['Secondary Schooling 1999'])**2

# %%
print(secondary_v_fertility.columns)
# Out:
# Index(['Fertility Rate 1999', 'Fertility Rate 2019',
#        'Secondary Schooling 1999', 'Secondary Schooling 2019',
#        'Schooling Difference'],
#       dtype='object', name='Indicator Name_x')

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.relplot(x = 'Fertility Rate 1999',
            y = "Secondary Schooling 1999", 
            data = secondary_v_fertility,
            kind= "scatter", 
            hue = 'Region',
            )

# Show plot
plt.title('Fertility Rate of Women 15 to 19 years old vs Secondary School enrollment (% gross) in 1999')
plt.xlabel('Adolescent fertility rate per 1000')
plt.ylabel('School enrollment, secondary, female (% gross)')
plt.ylim(0, 200)
plt.xlim(0,250)
plt.show()

# %%
secfert= sns.relplot(x = 'Fertility Rate 2019',
            y = "Secondary Schooling 2019", 
            data = secondary_v_fertility,
            kind= "scatter", 
            hue = 'Region',
            size = 'Schooling Difference',  
            sizes=(10, 200),  
            legend="brief"
            )


# Show plot
plt.title('Fertility Rate of Women 15 to 19 years old vs Secondary School enrollment (% gross) in 2019', fontsize = 10)
plt.xlabel('Adolescent fertility rate per 1000')
plt.ylabel('School enrollment, secondary, female (% gross)')
plt.ylim(0, 200)
plt.xlim(0,250)

plt.show()

# %%
# Add: Number of under-five deaths

# %%
# Replace all missing values with an empty string
cleaned_data = merged_data.fillna("")
display(HTML(cleaned_data.to_html(max_rows= 5, max_cols=150)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Indicator Name_x</th>
#       <th>Indicator Code</th>
#       <th>Short Name</th>
#       <th>Table Name</th>
#       <th>Long Name</th>
#       <th>2-alpha code</th>
#       <th>Currency Unit</th>
#       <th>Region</th>
#       <th>Income Group</th>
#       <th>WB-2 code</th>
#       <th>National accounts base year</th>
#       <th>SNA price valuation</th>
#       <th>System of National Accounts</th>
#       <th>Latest population census</th>
#       <th>Series Code</th>
#       <th>Topic</th>
#       <th>Indicator Name_y</th>
#       <th>Long definition</th>
#       <th>Periodicity</th>
#       <th>Source</th>
#       <th>License Type</th>
#       <th>1960</th>
#       <th>1961</th>
#       <th>1962</th>
#       <th>1963</th>
#       <th>1964</th>
#       <th>1965</th>
#       <th>1966</th>
#       <th>1967</th>
#       <th>1968</th>
#       <th>1969</th>
#       <th>1970</th>
#       <th>1971</th>
#       <th>1972</th>
#       <th>1973</th>
#       <th>1974</th>
#       <th>1975</th>
#       <th>1976</th>
#       <th>1977</th>
#       <th>1978</th>
#       <th>1979</th>
#       <th>1980</th>
#       <th>1981</th>
#       <th>1982</th>
#       <th>1983</th>
#       <th>1984</th>
#       <th>1985</th>
#       <th>1986</th>
#       <th>1987</th>
#       <th>1988</th>
#       <th>1989</th>
#       <th>1990</th>
#       <th>1991</th>
#       <th>1992</th>
#       <th>1993</th>
#       <th>1994</th>
#       <th>1995</th>
#       <th>1996</th>
#       <th>1997</th>
#       <th>1998</th>
#       <th>1999</th>
#       <th>2000</th>
#       <th>2001</th>
#       <th>2002</th>
#       <th>2003</th>
#       <th>2004</th>
#       <th>2005</th>
#       <th>2006</th>
#       <th>2007</th>
#       <th>2008</th>
#       <th>2009</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td>SP.ADO.TFRT</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>ZH</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>SP.ADO.TFRT</td>
#       <td>Health: Reproductive health</td>
#       <td>Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td>Adolescent fertility rate is the number of births per 1,000 women ages 15-19.</td>
#       <td>Annual</td>
#       <td>United Nations Population Division, World Population Prospects.</td>
#       <td>CC BY-4.0</td>
#       <td>140.18053</td>
#       <td>140.81025</td>
#       <td>141.66417</td>
#       <td>142.32495</td>
#       <td>143.45693</td>
#       <td>144.33115</td>
#       <td>145.29595</td>
#       <td>145.87149</td>
#       <td>145.74806</td>
#       <td>148.01200</td>
#       <td>149.57970</td>
#       <td>152.84677</td>
#       <td>153.95112</td>
#       <td>152.57050</td>
#       <td>152.50467</td>
#       <td>151.86791</td>
#       <td>150.53361</td>
#       <td>148.93110</td>
#       <td>146.64410</td>
#       <td>145.48472</td>
#       <td>143.75344</td>
#       <td>142.55813</td>
#       <td>141.19195</td>
#       <td>139.76381</td>
#       <td>138.78584</td>
#       <td>137.95322</td>
#       <td>136.12848</td>
#       <td>135.34615</td>
#       <td>133.91112</td>
#       <td>132.42260</td>
#       <td>132.84531</td>
#       <td>131.92260</td>
#       <td>128.65023</td>
#       <td>129.80065</td>
#       <td>128.79235</td>
#       <td>127.30655</td>
#       <td>128.23945</td>
#       <td>125.26200</td>
#       <td>123.86030</td>
#       <td>124.95802</td>
#       <td>123.13477</td>
#       <td>123.62917</td>
#       <td>121.93691</td>
#       <td>119.55752</td>
#       <td>118.82321</td>
#       <td>117.58424</td>
#       <td>116.40131</td>
#       <td>115.06088</td>
#       <td>114.93341</td>
#       <td>112.60237</td>
#       <td>111.75871</td>
#       <td>111.55859</td>
#       <td>109.53217</td>
#       <td>108.09280</td>
#       <td>107.69771</td>
#       <td>105.50183</td>
#       <td>103.22283</td>
#       <td>100.96353</td>
#       <td>99.49170</td>
#       <td>99.08557</td>
#       <td>97.41358</td>
#       <td>96.18144</td>
#       <td>94.68818</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td>Adults (ages 15+) and children (0-14 years) living with HIV</td>
#       <td>SH.HIV.TOTL</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>Africa Eastern and Southern</td>
#       <td>ZH</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>ZH</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>SH.HIV.TOTL</td>
#       <td>Health: Risk factors</td>
#       <td>Adults (ages 15+) and children (0-14 years) living with HIV</td>
#       <td>Adults and children living with HIV refers to the number of people ages 0-49 (adult ages 15-49 and children ages 0-14) who are infected with HIV.</td>
#       <td>Annual</td>
#       <td>UNAIDS estimates.</td>
#       <td>CC BY-4.0</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td

# %%
# Verify that missing values have been handled
missing_values_after = merged_data.isnull().sum().sort_values(ascending=False)
missing_values_after[missing_values_after > 0]  # This should ideally show an empty result
# Out:
# 2023            85835
# 1960            83191
# 1961            82637
# 1962            82523
# 1963            82474
#                 ...
# 2-alpha code     1410
# WB-2 code         940
# Short Name        470
# Table Name        470
# Long Name         470
# Length: 78, dtype: int64

# %%
# Sort the dataset by 'Region' and then by 'Country Name' within each region
arranged_data = cleaned_data.sort_values(by=['Region', 'Country Name']).reset_index(drop=True)

# Display the arranged data, showing each country and its region
arranged_data[['Country Name', 'Country Code', 'Region']].drop_duplicates()
# Out:
#                           Country Name Country Code              Region
# 0          Africa Eastern and Southern          AFE
# 470         Africa Western and Central          AFW
# 940                         Arab World          ARB
# 1410            Caribbean small states          CSS
# 1880    Central Europe and the Baltics          CEB
# ...                                ...          ...                 ...
# 122670                        Tanzania          TZA  Sub-Saharan Africa
# 123140                            Togo          TGO  Sub-Saharan Africa
# 123610                          Uganda          UGA  Sub-Saharan Africa
# 124080                          Zambia          ZMB  Sub-Saharan Africa
# 124550                        Zimbabwe          ZWE  Sub-Saharan Africa
#
# [266 rows x 3 columns]

# %%
# Define relevant indicators based on the questions of interest
indicators_of_interest = [
    # Health-related indicators
    'Prevalence of HIV, total (% of population ages 15-49)',
    'Prevalence of HIV, female (% ages 15-24)',
    'Prevalence of HIV, male (% ages 15-24)',
    'Incidence of HIV, all (per 1,000 uninfected population)',
    'Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)',
    'Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)',
    'Condom use at last high-risk sex, adult female (% ages 15-49)',
    'Condom use at last high-risk sex, adult male (% ages 15-49)',
    'Antiretroviral therapy coverage (% of people living with HIV)',
    'Birth rate, crude (per 1,000 people)',
    'Life expectancy at birth, female (years)',
    'Life expectancy at birth, male (years)',
    'Life expectancy at birth, total (years)',
    'Different mortality rates',

    # Education-related indicators
    'Literacy rate, adult female (% of females ages 15 and above)',
    'Literacy rate, adult male (% of males ages 15 and above)',
    'Literacy rate, adult total (% of people ages 15 and above)',
    'Literacy rate, youth male (% of males ages 15-24)',
    'Literacy rate, youth total (% of people ages 15-24)',
    'School enrollment, primary, female (% gross)',
    'School enrollment, primary, male (% gross)',
    'School enrollment, secondary, female (% gross)',
    'School enrollment, secondary, male (% gross)',
    'School enrollment, tertiary, female (% gross)',
    'Human capital index (HCI), female',
    'Human capital index (HCI), male',

    # Poverty and healthcare expenditure indicators
    'Proportion of population pushed below the $2.15 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
    'Proportion of population pushed below the $3.65 ($ 2017 PPP) poverty line by out-of-pocket health care expenditure (%)',
    'Proportion of population spending more than 10% of household consumption or income on out-of-pocket health care expenditure (%)',
    'Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)'
]

# Filter the data for these indicators
filtered_data = arranged_data[arranged_data['Indicator Name_x'].isin(indicators_of_interest)]

# Filter the columns for the years 2010 to 2023 and necessary metadata columns
year_columns = [str(year) for year in range(2010, 2024)]
columns_to_keep = ['Country Name', 'Country Code', 'Region', 'Indicator Name_x'] + year_columns

# Filter for relevant columns and verify
filtered_data = filtered_data[columns_to_keep]
display(HTML(filtered_data.to_html(max_rows=10, max_cols=20)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Region</th>
#       <th>Indicator Name_x</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>63</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td></td>
#       <td>Antiretroviral therapy coverage (% of people living with HIV)</td>
#       <td>24.64379</td>
#       <td>30.00350</td>
#       <td>35.83440</td>
#       <td>41.57617</td>
#       <td>47.54227</td>
#       <td>53.19825</td>
#       <td>59.30570</td>
#       <td>65.08863</td>
#       <td>68.43158</td>
#       <td>72.17497</td>
#       <td>75.17127</td>
#       <td>78.99182</td>
#       <td>82.42553</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td></td>
#       <td>Birth rate, crude (per 1,000 people)</td>
#       <td>37.94026</td>
#       <td>37.48399</td>
#       <td>36.92130</td>
#       <td>36.44714</td>
#       <td>36.02832</td>
#       <td>35.61331</td>
#       <td>35.18902</td>
#       <td>34.89254</td>
#       <td>34.61102</td>
#       <td>34.34145</td>
#       <td>33.91675</td>
#       <td>33.54627</td>
#       <td>33.14204</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>87</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td></td>
#       <td>Condom use at last high-risk sex, adult female (% ages 15-49)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>88</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td></td>
#       <td>Condom use at last high-risk sex, adult male (% ages 15-49)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>140</th>
#       <td>Africa Eastern and Southern</td>
#       <td>AFE</td>
#       <td></td>
#       <td>Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)</td>
#       <td>4.34168</td>
#       <td>4.07561</td>
#       <td>3.82277</td>
#       <td>3.54523</td>
#       <td>3.24420</td>
#       <td>2.95795</td>
#       <td>2.65861</td>
#       <td>2.34260</td>
#       <td>2.10265</td>
#       <td>1.87385</td>
#       <td>1.67389</td>
#       <td>1.48165</td>
#       <td>1.28005</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>124973</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Sub-Saharan Africa</td>
#       <td>School enrollment, primary, female (% gross)</td>
#       <td></td>
#       <td></td>
#       <td>101.13534</td>
#       <td>100.41488</td>
#       <td>99.64500</td>
#       <td>98.79634</td>
#       <td>97.62769</td>
#       <td>96.72829</td>
#       <td>96.42904</td>
#       <td>96.28593</td>
#       <td>96.64197</td>
#       <td>95.46800</td>
#       <td>95.38900</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>124975</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Sub-Saharan Africa</td>
#       <td>School enrollment, primary, male (% gross)</td>
#       <td></td>
#       <td></td>
#       <td>106.49299</td>
#       <td>105.94120</td>
#       <td>105.29200</td>
#       <td>104.33203</td>
#       <td>102.50370</td>
#       <td>100.40764</td>
#       <td>99.36014</td>
#       <td>98.68829</td>
#       <td>98.13673</td>
#       <td>96.56800</td>
#       <td>96.19400</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>124979</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Sub-Saharan Africa</td>
#       <td>School enrollment, secondary, female (% gross)</td>
#       <td></td>
#       <td></td>
#       <td>50.09587</td>
#       <td>49.84992</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>124981</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Sub-Saharan Africa</td>
#       <td>School enrollment, secondary, male (% gross)</td>
#       <td></td>
#       <td></td>
#       <td>55.09973</td>
#       <td>53.97830</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>124984</th>
#       <td>Zimbabwe</td>
#       <td>ZWE</td>
#       <td>Sub-Saharan Africa</td>
#       <td>School enrollment, tertiary, female (% gross)</td>
#       <td>5.99082</td>
#       <td>5.91722</td>
#       <td>6.13316</td>
#       <td>6.45997</td>
#       <td></td>
#       <td>9.45783</td>
#       <td>6.96000</td>
#       <td>7.98300</td>
#       <td>8.10000</td>
#       <td>9.80600</td>
#       <td>9.54400</td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
#For a random sampling, I select a random 10% sample of the data for analysis.
sample_data = filtered_data.sample(frac=0.1, random_state=20)
display(HTML(sample_data.to_html(max_rows=10, max_cols=20)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country Name</th>
#       <th>Country Code</th>
#       <th>Region</th>
#       <th>Indicator Name_x</th>
#       <th>2010</th>
#       <th>2011</th>
#       <th>2012</th>
#       <th>2013</th>
#       <th>2014</th>
#       <th>2015</th>
#       <th>2016</th>
#       <th>2017</th>
#       <th>2018</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>71326</th>
#       <td>Brazil</td>
#       <td>BRA</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>Prevalence of HIV, male (% ages 15-24)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>80058</th>
#       <td>Nicaragua</td>
#       <td>NIC</td>
#       <td>Latin America &amp; Caribbean</td>
#       <td>Literacy rate, youth male (% of males ages 15-24)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td>94.08000</td>
#       <td>89.64283</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>63068</th>
#       <td>Slovenia</td>
#       <td>SVN</td>
#       <td>Europe &amp; Central Asia</td>
#       <td>Condom use at last high-risk sex, adult male (% ages 15-49)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>21302</th>
#       <td>Sub-Saharan Africa (IDA &amp; IBRD countries)</td>
#       <td>TSS</td>
#       <td></td>
#       <td>Life expectancy at birth, total (years)</td>
#       <td>56.84737</td>
#       <td>57.55861</td>
#       <td>58.14101</td>
#       <td>58.66804</td>
#       <td>59.14266</td>
#       <td>59.56298</td>
#       <td>60.06902</td>
#       <td>60.47714</td>
#       <td>60.86303</td>
#       <td>61.24429</td>
#       <td>60.84889</td>
#       <td>60.24174</td>
#       <td>60.76440</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>46617</th>
#       <td>Denmark</td>
#       <td>DNK</td>
#       <td>Europe &amp; Central Asia</td>
#       <td>Condom use at last high-risk sex, adult female (% ages 15-49)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>8146</th>
#       <td>IBRD only</td>
#       <td>IBD</td>
#       <td></td>
#       <td>Literacy rate, adult male (% of males ages 15 and above)</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>107312</th>
#       <td>Congo, Dem. Rep.</td>
#       <td>COD</td>
#       <td>Sub-Saharan Africa</td>
#       <td>Life expectancy at birth, total (years)</td>
#       <td>56.41700</td>
#       <td>57.06900</td>
#       <td>57.24800</td>
#       <td>57.76200</td>
#       <td>58.29600</td>
#       <td>58.49000</td>
#       <td>59.06600</td>
#       <td>59.41100</td>
#       <td>59.94200</td>
#       <td>60.27600</td>
#       <td>59.73900</td>
#       <td>59.19300</td>
#       <td>59.74300</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>95476</th>
#       <td>Tunisia</td>
#       <td>TUN</td>
#       <td>Middle East &amp; North Africa</td>
#       <td>Birth rate, crude (per 1,000 people)</td>
#       <td>18.21100</td>
#       <td>18.93400</td>
#       <td>19.18400</td>
#       <td>19.33000</td>
#       <td>19.30300</td>
#       <td>19.11900</td>
#       <td>18.78000</td>
#       <td>18.39900</td>
#       <td>17.73700</td>
#       <td>17.21500</td>
#       <td>16.62800</td>
#       <td>16.09300</td>
#       <td>15.60000</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>66681</th>
#       <td>Ukraine</td>
#       <td>UKR</td>
#       <td>Europe &amp; Central Asia</td>
#       <td>Proportion of population spending more than 25% of household consumption or income on out-of-pocket health care expenditure (%)</td>
#       <td>0.89000</td>
#       <td>0.90000</td>
#       <td>1.04000</td>
#       <td>1.07000</td>
#       <td>0.85000</td>
#       <td>0.63000</td>
#       <td>1.31000</td>
#       <td>1.05000</td>
#       <td>1.23000</td>
#       <td>1.15000</td>
#       <td></td>
#       <td></td>
#       <td></td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>40305</th>
#       <td>Viet Nam</td>
#       <td>VNM</td>
#       <td>East Asia &amp; Pacific</td>
#       <td>Prevalence of HIV, female (% ages 15-24)</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td>0.10000</td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Generate summary statistics for the filtered dataset
summary_stats = filtered_data.describe(include='all')

# Display summary statistics
summary_stats
# Out:
#                        Country Name Country Code                 Region  \
# count                          7182         7182                   7182
# unique                          266          266                      8
# top     Africa Eastern and Southern          AFE  Europe & Central Asia
# freq                             27           27                   1566
#
#                                          Indicator Name_x  2010  2011  2012  \
# count                                                7182  7182  7182  7182
# unique                                                 27  2835  2850  2801
# top     Antiretroviral therapy coverage (% of people l...
# freq                                                  266  3380  3398  3431
#
#         2013  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# count   7182  7182  7182  7182  7182  7182  7182  7182  7182  7182  7182
# unique  2703  2808  2820  2741  2723  2739  2671  2611  2609  2367    74
# top
# freq    3536  3442  3378  3477  3508  3499  3581  3679  3661  4003  7109

# %% [markdown]
# How do literacy rates and school enrollment vary by gender across regions?/Are there significant gender differences in education and literacy across regions?
# Poverty and Healthcare Expenditure:
# What proportion of the population is pushed below poverty lines due to healthcare costs across regions?
#
# To filter the relevant indicators in arranged_data based on my questions of interest and time range (2010 to 2023), I will define relevant indicators by creating a list of the indicator names corresponding to each question of interest. Then, filter by Year Range. Since my analysis is focused on 2010 to 2023, I will select only the relevant columns for these years. Finally, filter arranged_data to include only the selected indicators and year range.

# %%
import seaborn as sns
import pandas as pd

# Filter for relevant indicators and select the year 2018
condom_data = filtered_data[
    (filtered_data['Indicator Name_x'].str.contains('Condom use', case=False, na=False)) & 
    (filtered_data['2018'].notna())
].rename(columns={'2018': '2018_condom'})

hiv_data = filtered_data[
    (filtered_data['Indicator Name_x'].str.contains('HIV Prevalence', case=False, na=False)) & 
    (filtered_data['2018'].notna())
].rename(columns={'2018': '2018_hiv'})


# Select only relevant columns
condom_data = condom_data[['Country Name', 'Region', '2018_condom']]
hiv_data = hiv_data[['Country Name', '2018_hiv']]
print(hiv_data.head(5))
print(condom_data.head(5))
# Out:
# Empty DataFrame
# Columns: [Country Name, 2018_hiv]
# Index: []
#                      Country Name Region 2018_condom
# 87    Africa Eastern and Southern
# 88    Africa Eastern and Southern
# 557    Africa Western and Central
# 558    Africa Western and Central
# 1027                   Arab World

# %%
# Merge the two datasets on 'Country Name' and 'Region'
merged_data = pd.merge(condom_data, hiv_data, on=['Country Name'], how='left')

print(merged_data.head(5))
# Out:
#                   Country Name Region 2018_condom 2018_hiv
# 0  Africa Eastern and Southern                         NaN
# 1  Africa Eastern and Southern                         NaN
# 2   Africa Western and Central                         NaN
# 3   Africa Western and Central                         NaN
# 4                   Arab World                         NaN

# %%
# Filter data for birth rate, life expectancy, and mortality indicators
birth_rate_data = filtered_data[filtered_data['Indicator Name_x'].str.contains('Birth rate')]
life_expectancy_data = filtered_data[filtered_data['Indicator Name_x'].str.contains('Life expectancy')]

# Define years for comparison
years = ['2012', '2022']

# Melt data to have 'Year' as a column for easy comparison
birth_rate_data_melted = birth_rate_data.melt(id_vars=['Region'], value_vars=years, var_name='Year', value_name='Birth Rate')
life_expectancy_data_melted = life_expectancy_data.melt(id_vars=['Region'], value_vars=years, var_name='Year', value_name='Life Expectancy')

# Set up the figure and axis
plt.figure(figsize=(25, 30))
plt.rcParams.update({'font.size': 12})
# Plot for Birth Rate
plt.subplot(3, 1, 1)
sns.boxplot(data=birth_rate_data_melted, x='Region', y='Birth Rate', hue='Year', palette="Set2")
plt.title('Regional Differences in Birth Rates (2013 vs 2022)')
plt.xlabel('')
plt.ylabel('Birth Rate (per 1,000 people)')
plt.ylim(0, 50)


# Plot for Life Expectancy
plt.subplot(3, 1, 2)
sns.boxplot(data=life_expectancy_data_melted, x='Region', y='Life Expectancy', hue='Year', palette="Set2")
plt.title('Regional Differences in Life Expectancy (2013 vs 2022)')
plt.xlabel('')
plt.ylabel('Life Expectancy (years)')
plt.gca().invert_yaxis()
plt.ylim(0, 100)


plt.show()

# %%
# Filter data for literacy rates and school enrollment by gender
literacy_data = filtered_data[filtered_data['Indicator Name_x'].str.contains('Literacy rate')]
enrollment_data = filtered_data[filtered_data['Indicator Name_x'].str.contains('School enrollment')]

# Select the year for comparison
year = '2022'

# %%
# Create a Gender column based on Indicator Name for both literacy and enrollment data
literacy_data['Gender'] = literacy_data['Indicator Name_x'].apply(lambda x: 'Female' if 'female' in x.lower() else 'Male' if 'male' in x.lower() else 'Unknown')
enrollment_data['Gender'] = enrollment_data['Indicator Name_x'].apply(lambda x: 'Female' if 'female' in x.lower() else 'Male' if 'male' in x.lower() else 'Unknown')

# Now filter to include only male and female rows (exclude 'Unknown' if any)
literacy_data = literacy_data[literacy_data['Gender'] != 'Unknown']
enrollment_data = enrollment_data[enrollment_data['Gender'] != 'Unknown']
# Out:
# /var/folders/vt/8zqwv5_51777lk_0p42g3sdr0000gn/T/ipykernel_27884/3418646452.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   literacy_data['Gender'] = literacy_data['Indicator Name_x'].apply(lambda x: 'Female' if 'female' in x.lower() else 'Male' if 'male' in x.lower() else 'Unknown')
# /var/folders/vt/8zqwv5_51777lk_0p42g3sdr0000gn/T/ipykernel_27884/3418646452.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enrollment_data['Gender'] = enrollment_data['Indicator Name_x'].apply(lambda x: 'Female' if 'female' in x.lower() else 'Male' if 'male' in x.lower() else 'Unknown')

# %%
plt.figure(figsize=(25, 20))

plt.rcParams.update({'font.size': 12})
# Boxplot for Literacy Rates by Gender
plt.subplot(2, 1, 1)
sns.boxplot(data=literacy_data, x='Region', y=year, hue='Gender')
plt.title('Literacy Rates by Gender Across Regions')
plt.xlabel('')
plt.ylabel('Literacy Rate (%)')
plt.legend(title='Gender')
plt.ylim(10, 100)


# Boxplot for School Enrollment by Gender
plt.subplot(2, 1, 2)
sns.boxplot(data=enrollment_data, x='Region', y=year, hue='Gender')
plt.title('School Enrollment by Gender Across Regions')
plt.xlabel('Region')
plt.ylabel('Enrollment Rate (%)')
plt.legend(title='Gender')
plt.ylim(0, 160)
plt.show()

# %%
enrollment_data = filtered_data[filtered_data['Indicator Name_x'].str.contains('School enrollment')]

plt.figure(figsize=(12, 6))
sns.barplot(data=enrollment_data, x='Region', y='2022', hue='Indicator Name_x')
plt.title('School Enrollment by Gender and Region (2022)')
plt.xticks(rotation=45)
plt.xlabel('Region')
plt.ylabel('Enrollment Rate (%)')
plt.legend(title='Indicator', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(25, 20))
plt.rcParams.update({'font.size': 12})
sns.boxplot(data=filtered_data[filtered_data['Indicator Name_x'].str.contains('Literacy rate')],
            x='Region', y='2021', hue='Indicator Name_x')  # Adjust year as needed
plt.title('Literacy Rates by Gender and Region (2021)', fontsize = 18)
plt.xticks(rotation=45)
plt.xlabel('Region')
plt.ylabel('Literacy Rate (%)')
plt.legend(title='Indicator', title_fontsize=16, fontsize=14)
plt.ylim(20, 100)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Choose the quantitative variable column for analysis (here I use '2015')
quantitative_variable = pd.to_numeric(arranged_data['2015'], errors='coerce').dropna()  # Convert to numeric and drop NaNs

# Number of bootstrap samples
n_bootstrap_samples = 3000

# Array to store the bootstrapped medians
bootstrap_medians = []

# Perform bootstrapping
for _ in range(n_bootstrap_samples):
    sample = np.random.choice(quantitative_variable, size=len(quantitative_variable), replace=True)
    bootstrap_medians.append(np.median(sample))

# Calculate the 95% confidence interval
lower_bound = np.percentile(bootstrap_medians, 2.5)
upper_bound = np.percentile(bootstrap_medians, 97.5)

# Plot the distribution of bootstrap medians
plt.figure(figsize=(10, 6))
plt.hist(bootstrap_medians, bins=30, edgecolor='k', alpha=0.7)
plt.axvline(np.median(quantitative_variable), color='blue', linestyle='--', label='Observed Median')
plt.axvline(lower_bound, color='red', linestyle='--', label='95% CI Lower Bound')
plt.axvline(upper_bound, color='red', linestyle='--', label='95% CI Upper Bound')
plt.title('Bootstrap Distribution of the Median for 2015')
plt.xlabel('Median')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# Print results
print(f"Observed Median for 2015: {np.median(quantitative_variable)}")
print(f"95% Confidence Interval for Median: [{lower_bound}, {upper_bound}]")
# Out:
# Observed Median for 2015: 66.62960266816836
# 95% Confidence Interval for Median: [65.4597642606023, 67.7599839701598]

# %%
# Filter and convert data to numeric, handling non-numeric values
life_expectancy_data = pd.to_numeric(
    filtered_data[filtered_data['Indicator Name_x'] == 'Life expectancy at birth, total (years)']['2015'],
    errors='coerce'
).dropna()

# Simulate bootstrap samples
bootstrap_medians = []
for _ in range(3000):
    sample = np.random.choice(life_expectancy_data, size=int(len(life_expectancy_data) * 0.1), replace=True)
    bootstrap_medians.append(np.median(sample))

# Plot the distribution of bootstrap medians
plt.figure(figsize=(8, 5))
sns.histplot(bootstrap_medians, kde=True, color='#FF5733')
plt.title('Bootstrap Distribution of Median Life Expectancy at Birth (2015)')
plt.xlabel('Median Life Expectancy (years)')
plt.ylabel('Frequency')
plt.show()
